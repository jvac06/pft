# %%
#dependencies for EDA
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
# %store -r order_reduced

# %%
order_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 188983 entries, 0 to 188982
# Data columns (total 23 columns):
# requested_date             188983 non-null datetime64[ns]
# confirmed_date             188983 non-null datetime64[ns]
# material_avail_date        188983 non-null datetime64[ns]
# load_date                  188983 non-null datetime64[ns]
# plan_goods_issue_date      188983 non-null datetime64[ns]
# sales_district_code        188983 non-null object
# division                   188983 non-null int64
# sold_to                    188983 non-null int64
# ship_to                    188983 non-null int64
# route                      188983 non-null object
# ship_to_city               188983 non-null object
# ship_to_state              188983 non-null object
# sku                        188983 non-null int64
# material_description       188983 non-null object
# order_qty_sales_units      188983 non-null float64
# confirmed_qty              188983 non-null float64
# ...

# %%
order_reduced.sample(5)
# Out:
#        requested_date confirmed_date material_avail_date  load_date  \
# 173714     2020-01-04     2020-01-06          2019-12-04 2019-12-04
# 76097      2016-04-15     2016-04-15          2016-06-23 2016-06-23
# 186288     2020-03-01     2020-05-21          2020-05-19 2020-05-19
# 163069     2019-08-23     2019-08-23          2019-08-21 2019-08-21
# 101606     2017-04-17     2017-04-17          2017-04-12 2017-04-12
#
#        plan_goods_issue_date sales_district_code  division    sold_to  \
# 173714            2019-12-19              103613         3  100091978
# 76097             2016-06-23                             3  100051178
# 186288            2020-05-20              100311         3  100051178
# 163069            2019-08-22              100209         2  100092165
# 101606            2017-04-16                             3  100060909
#
#           ship_to   route  ...              material_description  \
# 173714  100943045  CM0591  ...  L 3 1/2X3 1/2X5/16 A588-B 40'00"
# ...
